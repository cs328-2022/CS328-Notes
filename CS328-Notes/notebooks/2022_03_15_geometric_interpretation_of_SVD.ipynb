# %% [markdown]
# <br>
#
# <b>Geometrical view of SVD</b>
#
# ![geometrical interpretation.jpg](data:image/jpeg;base64,...)
#
#
#
#
#
#
# Fig credit: Math for CSLecture
#
#
#
#
# The above image shows how the points get linearly transformed by A, i.e. A v= σ u (equation 1)
# <br>
# svd says 3 important things about this transormation
#
# 1.  The u<sub>i</sub> vectors in svd decompostion of A form the axes of the new  transformed subspace
# 2. the length of each axis is equal to coressponding σ<sub>i</sub>
# 3. the preimage of u<sub>i</sub> is the corresponding v<sub>i</sub> of the svd of A (from equation 1)

# %% [markdown]
# The SVD has a nice, simple geometric interpretation. It is very easy to draw in 2-Dimension.
#
# let U=
# \begin{bmatrix}
# u_1&
# u_2
# \end{bmatrix}
#
# \V^{T}=
# \begin{bmatrix}
# v_1^{T}\\
# v_2^{T}
# \end{bmatrix}
#
# let A=UD{V^T}
#
# 𝐴𝑉 = 𝑈𝐷{𝑉^𝑇}𝑉
# 𝐴𝑉 = 𝑈𝐷 ({𝑉^𝑇}𝑉)
# 𝐴𝑉 = 𝑈𝐷𝐼
# 𝐴𝑉 = 𝑈𝐷
#
#
#
#
# Let us take the unit circle and linear transformed by A, we get an ellipse. The pre-factor of D is U,
# 𝑢1 𝑢2 are the major and minor axis of the ellipse. The post factor of D is {𝑉^{T}}
# . The vector 𝑣1
# , 𝑣2
# in 𝑉^{𝑇}
# are the vectors that get mapped to the major and the minor axis. In 3-D the sphere is transformed to
# ellipsoid.
# Another way to say sum of this is the set 𝐴𝑣1 = 𝜎𝑖𝑢𝑖
#
# Which you can see by this 2-D example
# \v_1
#   \begin{bmatrix}
#    V_1^T\\
#    V_2^T
#    \end{bmatrix}
#    =
#    \begin{bmatrix}
#     1\\
#     0
#     \end{bmatrix}
#
#
# Above discussion extended to in general mostly. If A has full rank now the singular value of A are the
# lengths of the n principle semi axis of the ellipsoid the length are𝜎1𝜎2 … 𝜎𝑛 the n left singular vector
# of the A are the directions 𝑢1
# , 𝑢2
# , . . 𝑢𝑛 aligned the n semi axis of ellipsoid. The n right singular
# vectors of A are the directions 𝑣1
# , 𝑣2
# , … 𝑣𝑛 in sphere which the matrix A is transformed into the semi
# axis of the ellipsoid.
#
#
# A rank deficient matrix is one whose range is a sub space of 𝑅
# 3
# so it maps the sphere to flat ellipse
# rather than ellipsoid.
#
# Here one of the singular value is zero, 𝑢3
# is normal to the ellipse
#
# let V^T v_3
# =
# \begin{bmatrix}
#  0\\
#  0\\
#  1
#  \end{bmatrix}
#
# and
# D
#  \begin{bmatrix}
#  0\\
#  0\\
#  1
#  \end{bmatrix}
# =
# \begin{bmatrix}
#  0\\
#  0\\
#  0
#  \end{bmatrix}
#
#
# **Application.**
# **Rank deficient least square:**
#
# The linear system is 𝐴𝑥 = 𝑦
# x=(A^{-1})y
#
# The above process is simplest but not fastest. The process is facts if the singular values are zero. If the
# matrix A is singular the this work.
#
#
# **How to solve**
#
#
# A is a 𝑛 × 𝑛 square matrix
#
# And rank of A is 𝑟 > 𝑛
#
# The system will not have unique solution if 𝐴𝑥∗ − 𝑦 is minimum
#
# 𝐴 (𝑥∗ + 𝑏) − 𝑦for any vector 𝑏 ∈ null (A) [Ab=0]
#
# This system is like over and in determined SVD we can solve easily.
#
# First we define residual. Sum of the square of the residual is minimum by least square method. Now
# to minimize the SVD of A and if then transfer it by U^T
#
#  ||𝐴𝑥 − 𝑦||^2 = ||𝑈𝐷𝑉𝑇𝑥 − 𝑦||^2
# = ||𝐼𝑈𝐷𝑉𝑇𝑥 − 𝐼𝑦||^2
# = ||𝑈𝑈𝑇𝑈𝐷𝑉𝑇𝑥 − 𝑈𝑈𝑇𝑦||^2
# = ||𝑈|| ||𝐼𝐷𝑉𝑇𝑥 − 𝑈𝑇𝑦||^2
# = ||𝐷𝑉𝑇𝑥 − 𝑈𝑇𝑦||^2
# =||V^T(
#   \begin{bmatrix} D & 0\\ 0 & 0 \end{bmatrix}
#   ) - y(
#     \begin{bmatrix}
#  u_1^T\\
#  u_2^T
#  \end{bmatrix}
#  )||^2
#
#
#
#
# the first term can be made zero. The second term is residual
#
# if we let 𝑏 = 𝑣𝑇𝑥 and 𝑘 = 𝑢1𝑇y
#
# Than split b into
# \begin{bmatrix}
#  b_1\\
#  b_2
#  \end{bmatrix}
#
#  which gives
#
#  \begin{bmatrix}
#  D_1&0
#  \end{bmatrix}
#  \begin{bmatrix}
#  b_1\\
#  b_2
#  \end{bmatrix}
#  =k
#
#  𝐷1𝑏1 = 𝑘
#
# Now we will go for the minimizing solution than 𝑥 = 𝑉1𝑏1
#
# Briefly 𝑥 = 𝑉𝐷1^−1𝑘
#
# 𝑥 = 𝑉1𝐷1−1𝑈1𝑇y

# %% [markdown]
# $$
# \operatorname{Pr}(|X-\mathbf{E}[X]| \geq a) \leq \frac{\operatorname{Var}[X]}{a^{2}}
# $$

# %% [markdown]
#  \begin{bmatrix} \Phi_{11} & \Phi_{12} \\ \Phi_{21} & \Phi_{22} \end{bmatrix}
#  =
#   \begin{bmatrix}
#    X_{22}^{t} Y_{11} - X_{12} Y_{21} &
#    X_{22} Y_{12} - X_{12} Y_{22} \\
#    X_{11} Y_{21} - X_{21} Y_{11} &
#    X_{11} Y_{22} - X_{21} Y_{12}
#    \end{bmatrix}

# %% [markdown]
#  \begin{bmatrix} \Phi_{11} & \Phi_{12} \\ \Phi_{21} & \Phi_{22} \end{bmatrix}
#  =
#  \frac{1}{\det(X)}
#   \begin{bmatrix}
#    X_{22}^{t} Y_{11} - X_{12} Y_{21} &
#    X_{22} Y_{12} - X_{12} Y_{22} \\
#    X_{11} Y_{21} - X_{21} Y_{11} &
#    X_{11} Y_{22} - X_{21} Y_{12}
#    \end{bmatrix}

# %% [markdown]
# <b>References</b>:
#
# https://ocw.mit.edu/courses/mathematics/18-06-linear-algebra-spring-2010/video-lectures/lecture-29-singular-value-decomposition/
#
# "Spectral Learning on Matrices and Tensors" textbook
